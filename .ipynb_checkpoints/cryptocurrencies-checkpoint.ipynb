# %%
# Initial imports
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from pathlib import Path

# %% [markdown]
# ## Opening Cryptocurrency Data

# %%
file_path = Path("Resources/crypto_data.csv")
crypto_df = pd.read_csv(file_path, index_col = 0)
crypto_df.head(10)
# Out:
#        CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42      42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365     365Coin       X11       True   PoW/PoS              NaN
# 404     404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611   SixEleven   SHA-256       True       PoW              NaN
# 808         808   SHA-256       True   PoW/PoS     0.000000e+00
# 1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 2015  2015 coin       X11       True   PoW/PoS              NaN
# BTC     Bitcoin   SHA-256       True       PoW     1.792718e+07
# ETH    Ethereum    Ethash       True       PoW     1.076842e+08
# LTC    Litecoin    Scrypt       True       PoW     6.303924e+07
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# 1337    314159265359
# 2015               0
# BTC         21000000
# ETH                0
# LTC         84000000

# %%
# List dataframe data types
crypto_df.dtypes
# Out:
# CoinName            object
# Algorithm           object
# IsTrading             bool
# ProofType           object
# TotalCoinsMined    float64
# TotalCoinSupply     object
# dtype: object

# %%
# Keep only cryptocurrencies that are trading
crypto_df = crypto_df.loc[crypto_df['IsTrading'] == True]
crypto_df
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42        42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 365       365Coin          X11       True   PoW/PoS              NaN
# 404       404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 611     SixEleven      SHA-256       True       PoW              NaN
# 808           808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# SERO   Super Zero       Ethash       True       PoW              NaN
# UOS           UOS      SHA-256       True      DPoI              NaN
# BDX        Beldex  CryptoNight       True       PoW     9.802226e+08
# ZEN       Horizen     Equihash       True       PoW     7.296538e+06
# XBC   BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# ...

# %%
# Remove the 'IsTrading' column
crypto_df = crypto_df.drop(columns = 'IsTrading')
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 365       365Coin          X11   PoW/PoS              NaN      2300000000
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 611     SixEleven      SHA-256       PoW              NaN          611000
# 808           808      SHA-256   PoW/PoS     0.000000e+00               0
# ...           ...          ...       ...              ...             ...
# SERO   Super Zero       Ethash       PoW              NaN      1000000000
# UOS           UOS      SHA-256      DPoI              NaN      1000000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [1144 rows x 5 columns]

# %%
# Remove rows with at least 1 null value
crypto_df.isnull().sum()
# Out:
# CoinName             0
# Algorithm            0
# ProofType            0
# TotalCoinsMined    459
# TotalCoinSupply      0
# dtype: int64

# %%
# Remove rows with at least 1 null value
crypto_df = crypto_df.dropna()
crypto_df.isnull().sum()
# Out:
# CoinName           0
# Algorithm          0
# ProofType          0
# TotalCoinsMined    0
# TotalCoinSupply    0
# dtype: int64

# %%
# Remove rows with cryptocurrencies having no coins mined
crypto_df = crypto_df.loc[crypto_df['TotalCoinsMined'] != 0]
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337    EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ETH      Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# GAP       Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [533 rows x 5 columns]

# %%
# Store the'CoinName'column
cryptoname_df = pd.DataFrame(data = crypto_df, columns = ['CoinName'])
cryptoname_df
# Out:
#          CoinName
# 42        42 Coin
# 404       404Coin
# 1337    EliteCoin
# BTC       Bitcoin
# ETH      Ethereum
# ...           ...
# ZEPH       ZEPHYR
# GAP       Gapcoin
# BDX        Beldex
# ZEN       Horizen
# XBC   BitcoinPlus
#
# [533 rows x 1 columns]

# %%
# Drop the 'CoinName' column
crypto_df = crypto_df.drop(columns = 'CoinName')
crypto_df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42         Scrypt   PoW/PoS     4.199995e+01              42
# 404        Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       SHA-256       PoW     1.792718e+07        21000000
# ETH        Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# ZEPH      SHA-256      DPoS     2.000000e+09      2000000000
# GAP        Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX   CryptoNight       PoW     9.802226e+08      1400222610
# ZEN      Equihash       PoW     7.296538e+06        21000000
# XBC        Scrypt       PoS     1.283270e+05         1000000
#
# [533 rows x 4 columns]

# %%
# Create dummy variables for text features
crypto = pd.get_dummies(crypto_df, columns=['Algorithm', 'ProofType'])
crypto
# Out:
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 42       4.199995e+01              42                                 0
# 404      1.055185e+09       532000000                                 0
# 1337     2.927942e+10    314159265359                                 0
# BTC      1.792718e+07        21000000                                 0
# ETH      1.076842e+08               0                                 0
# ...               ...             ...                               ...
# ZEPH     2.000000e+09      2000000000                                 0
# GAP      1.493105e+07       250000000                                 0
# BDX      9.802226e+08      1400222610                                 0
# ZEN      7.296538e+06        21000000                                 0
# XBC      1.283270e+05         1000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# ...

# %% [markdown]
# ### Yes, the columns of the dataset changed because the results of Algorithm and ProofType change to 0 and 1 and each category has become a column.

# %%
# Standardize data
crypto_scaled = StandardScaler().fit_transform(crypto)
crypto_scaled
# Out:
# array([[-0.11674788, -0.15286468, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [-0.09358885, -0.14499604, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [ 0.52587231,  4.4937636 , -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        ...,
#        [-0.09523411, -0.13215444, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [-0.11658774, -0.15255408, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [-0.11674507, -0.15284989, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ]])

# %% [markdown]
# ## Dimensionality Reduction

# %%
# Applying PCA to reduce dimensions to 3

# Initialize PCA model
pca = PCA(n_components=0.99)

# Get three principal components for the crypto data.
crypto_pca = pca.fit_transform(crypto_scaled)

# %%
# Transform PCA data to a DataFrame
crypto_pca_df = pd.DataFrame(data=crypto_pca)
crypto_pca_df.head()
# Out:
#          0         1         2         3             4             5   \
# 0 -0.333759  1.010335 -0.645813  0.009061  6.606612e-14  2.222495e-14
# 1 -0.317078  1.010467 -0.646245  0.009004  6.616043e-14  2.224733e-14
# 2  2.308741  1.636182 -0.741287  0.027146  9.335308e-14  2.597862e-14
# 3 -0.144347 -1.318206  0.216681 -0.007076 -2.344045e-14 -5.804113e-15
# 4 -0.151002 -2.029159  0.440925 -0.010285 -4.727542e-14 -1.177135e-14
#
#              6             7         8         9   ...            77  \
# 0 -2.653436e-14 -1.707312e-14  0.000677 -1.313000  ...  2.066727e-14
# 1 -2.651463e-14 -1.706173e-14  0.000074 -1.315755  ...  2.105044e-14
# 2 -4.224173e-14 -2.654556e-14 -0.049574 -1.540532  ... -4.433083e-13
# 3  1.051530e-14  7.693371e-15 -0.003528  0.282703  ... -6.592751e-14
# 4  1.936689e-14  1.379311e-14  0.024224  0.520040  ...  2.519116e-13
#
#          78        79        80        81        82        83        84  \
# ...

# %%
# Fetch the explained variance
pca.explained_variance_ratio_
# Out:
# array([0.02737323, 0.02098076, 0.02011739, 0.02003802, 0.02003759,
#        0.02003759, 0.02003759, 0.02003759, 0.02001633, 0.01832347,
#        0.01721032, 0.01706225, 0.01596347, 0.0156419 , 0.01519981,
#        0.01405625, 0.01294651, 0.01211625, 0.01182081, 0.01082053,
#        0.01050008, 0.01028043, 0.0102003 , 0.01018272, 0.01016953,
#        0.01014678, 0.01013328, 0.01008996, 0.01007654, 0.01007561,
#        0.01007561, 0.01007561, 0.01007392, 0.01006498, 0.01005794,
#        0.01005667, 0.01005237, 0.01005044, 0.01004558, 0.01004417,
#        0.01003786, 0.01003766, 0.01003766, 0.01003699, 0.01003531,
#        0.01003197, 0.0100302 , 0.01002535, 0.0100199 , 0.0100188 ,
#        0.0100188 , 0.0100188 , 0.0100188 , 0.0100188 , 0.0100188 ,
#        0.0100188 , 0.0100188 , 0.0100188 , 0.0100188 , 0.0100188 ,
#        0.0100188 , 0.0100188 , 0.0100188 , 0.0100188 , 0.0100188 ,
#        0.0100188 , 0.0100188 , 0.0100188 , 0.0100188 , 0.0100188 ,
# ...

# %% [markdown]
# ## Cluster Analysis with k-Means

# %%
# Finding the best value for k
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(crypto_pca_df)
    inertia.append(km.inertia_)

# Creating the Elbow Curve
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)

plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(list(range(11)))
plt.title('Elbow Curve')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# ## Conclusions

# %% [markdown]
# ### After preparing the data, creating the cluster analysis, amd visualizing the elbow curve,  it can be concluded that the best k value is 4 meaning that cryptocurrencies can be categorized in 4 clusters. After separating the cryptocurrencies in this four clusters, the client can decide which cluster performs better and invest in that cryptocurrencies.
